# %%
import pandas as pd

data = {'ID': [1, 2, 3],
        'Details': [{'name': 'Alice', 'age': 30},
                    {'name': 'Bob', 'city': 'New York'},
                    {'name': 'Charlie', 'age': 25, 'occupation': 'Engineer'}]}
df = pd.DataFrame(data)
print(df)
# Out:
#    ID                                            Details
# 0   1                       {'name': 'Alice', 'age': 30}
# 1   2                {'name': 'Bob', 'city': 'New York'}
# 2   3  {'name': 'Charlie', 'age': 25, 'occupation': '...

# %%
p = df.iloc[0]
p
# Out:
# ID                                    1
# Details    {'name': 'Alice', 'age': 30}
# Name: 0, dtype: object

# %%
p["Details"]["name"]
# Out:
# str

# %%
self.data['timestamp'].unique()
sorted_date_strings = sorted(date_strings, key=lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))

# %%
from dataclasses import dataclass


@dataclass
class Order:
    symbol: str

o = Order("test")

o

# %%
min(.2, .4)
# Out:
# 0.2

# %%
import yfinance as yf

# Fetch AAPL stock data with a 1-hour timeframe
aapl = yf.Ticker("AAPL")
data = aapl.history(period="60d", interval="1h")

# %%
 type(data['Close'])
# Out:
# pandas.core.series.Series

# %%
data['EMA12'] = data['Close'].ewm(span=4, adjust=False).mean()

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-09-04 09:30:00-04:00  238.449997  239.893204  237.039993  237.690002
# 2025-09-04 10:30:00-04:00  237.679993  238.100006  237.074997  237.399994
# 2025-09-04 11:30:00-04:00  237.389999  237.674606  236.740005  237.160004
# 2025-09-04 12:30:00-04:00  237.149994  238.089996  236.970001  238.039993
# 2025-09-04 13:30:00-04:00  238.040100  238.389999  237.509995  238.059998
# ...                               ...         ...         ...         ...
# 2025-11-26 11:30:00-05:00  279.029999  279.529999  278.869995  279.079010
# 2025-11-26 12:30:00-05:00  279.070007  279.290009  278.095001  278.549988
# 2025-11-26 13:30:00-05:00  278.559998  278.581787  277.924988  278.260010
# 2025-11-26 14:30:00-05:00  278.260101  278.940002  278.010010  278.079987
# 2025-11-26 15:30:00-05:00  278.070007  278.299988  277.149994  277.470001
#
#                              Volume  Dividends  Stock Splits       EMA12
# Datetime
# 2025-09-04 09:30:00-04:00  12016131        0.0           0.0  237.690002
# 2025-09-04 10:30:00-04:00   5223309        0.0           0.0  237.573999
# 2025-09-04 11:30:00-04:00   3678939        0.0           0.0  237.408401
# 2025-09-04 12:30:00-04:00   3071522        0.0           0.0  237.661038
# 2025-09-04 13:30:00-04:00   5093419        0.0           0.0  237.820622
# ...                             ...        ...           ...         ...
# 2025-11-26 11:30:00-05:00   2586354        0.0           0.0  278.550301
# 2025-11-26 12:30:00-05:00   1871279        0.0           0.0  278.550176
# 2025-11-26 13:30:00-05:00   1426945        0.0           0.0  278.434109
# 2025-11-26 14:30:00-05:00   1953254        0.0           0.0  278.292460
# 2025-11-26 15:30:00-05:00   9116002        0.0           0.0  277.963477
#
# [420 rows x 8 columns]
